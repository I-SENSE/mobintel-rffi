# %%
import numpy as np;
import matplotlib.pyplot as plt
import scipy.fft
import seaborn as sns;

from data_utils import *

DATASET = '/Users/stepanmazokha/Desktop/wisig_manytx_rffi_dataset/'
FIG_DIR = '/Users/stepanmazokha/Desktop/figs/'

# %%
compact_dataset = load_compact_pkl_dataset(DATASET, 'ManyTx')

data = compact_dataset['data']
tx_list = compact_dataset['tx_list']
rx_list = compact_dataset['rx_list']
capture_date_list = compact_dataset['capture_date_list']

# %%
def generate_spectrum(data, tx_id, rx_id, date_id, equalized):
    # data shape: [tx(6), rx(12), date(4), equalized? (1-unprocessed, 2-equalized), # of signals(1000), # of samples(256), I/Q split(2)]
    N = 256

    samples = data[tx_id][rx_id][date_id][equalized]

    if len(samples) < 50:
        print("Not enough samples: " + str(len(samples)))
        return

    # Convert into frequency domain (spectrum)
    spectrum = np.zeros(shape=(N-1, 50), dtype='float32')
    for packet_id in np.arange(50):
        packet = np.array(samples[packet_id])
        signal = packet[:, 0] + 1j * packet[:, 1]

        yf = scipy.fft.fft(signal, n=256)
        # xf = scipy.fft.fftfreq(N, T)[:N//2]
        # plt.plot(xf, 2.0/N * np.abs(yf[0:N//2]))
        # plt.show()

        # Generate channel independent spectrogram.
        yf_ind = yf[1:]/yf[:-1]
        # xf_ind = xf[1:]
        # plt.plot(xf_ind, 2.0/256 * np.abs(yf_ind[0:256//2-1]))
        # plt.show()

        spectrum[:, packet_id] = np.abs(yf_ind)

    spectrum_amp = np.log10(np.abs(spectrum)**2)

    # Plot the spectrogram using seaborn heatmap
    plt.figure(figsize=(12, 8))
    sns.heatmap(spectrum_amp, cmap='viridis', cbar=True)
    plt.title("Spectrogram")
    plt.xlabel("Packet ID")
    plt.ylabel("Frequency Bin")
    plt.savefig(FIG_DIR + 'spectrogram-' + str(tx_id) + "-" + str(rx_id) + ".png")
    plt.close()

# %%
for tx_id in np.arange(1, 30):
    generate_spectrum(data, tx_id, 1, 1, 0)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 for tx_id in np.arange(1, 30):
# ----> 2     generate_spectrum(data, tx_id, 1, 1, 0)
#
# Cell In[3], line 38, in generate_spectrum(data, tx_id, rx_id, date_id, equalized)
#      36 plt.xlabel("Packet ID")
#      37 plt.ylabel("Frequency Bin")
# ---> 38 plt.savefig(FIG_DIR + 'spectrogram-' + str(tx_id) + "-" + str(rx_id) + ".png")
#      39 plt.close()
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages/matplotlib/pyplot.py:1223, in savefig(*args, **kwargs)
#    1220 fig = gcf()
#    1221 # savefig default implementation has no return, so mypy is unhappy
#    1222 # presumably this is here because subclasses can return?
# -> 1223 res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
#    1224 fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1225 return res
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages/matplotlib/figure.py:3388, in Figure.savefig(self, fname, transparent, **kwargs)
#    3386     for ax in self.axes:
#    3387         _recursively_make_axes_transparent(stack, ax)
# -> 3388 self.canvas.print_figure(fname, **kwargs)
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages/matplotlib/backend_bases.py:2218, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2214 try:
#    2215     # _get_renderer may change the figure dpi (as vector formats
#    2216     # force the figure dpi to 72), so we need to set it again here.
#    2217     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2218         result = print_method(
#    2219             filename,
#    2220             facecolor=facecolor,
#    2221             edgecolor=edgecolor,
#    2222             orientation=orientation,
#    2223             bbox_inches_restore=_bbox_inches_restore,
#    2224             **kwargs)
#    2225 finally:
#    2226     if bbox_inches and restore_bbox:
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages/matplotlib/backend_bases.py:2068, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2064     optional_kws = {  # Passed by print_figure for other renderers.
#    2065         "dpi", "facecolor", "edgecolor", "orientation",
#    2066         "bbox_inches_restore"}
#    2067     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2068     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2069         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2070 else:  # Let third-parties do as they see fit.
#    2071     print_method = meth
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:496, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs)
#     449 def print_png(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     450     """
#     451     Write the figure to a PNG file.
#     452
#    (...)
#     494         *metadata*, including the default 'Software' key.
#     495     """
# --> 496     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:445, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     440 """
#     441 Draw the canvas, then save it using `.image.imsave` (to which
#     442 *pil_kwargs* and *metadata* are forwarded).
#     443 """
#     444 FigureCanvasAgg.draw(self)
# --> 445 mpl.image.imsave(
#     446     filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     447     dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages/matplotlib/image.py:1676, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1674 pil_kwargs.setdefault("format", format)
#    1675 pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1676 image.save(fname, **pil_kwargs)
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages/PIL/Image.py:2563, in Image.save(self, fp, format, **params)
#    2561         fp = builtins.open(filename, "r+b")
#    2562     else:
# -> 2563         fp = builtins.open(filename, "w+b")
#    2564 else:
#    2565     fp = cast(IO[bytes], fp)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/stepanmazokha/Desktop/figs/spectrogram-1-1.png'

# %%
slc = slice(0,256)
x = np.zeros((1000, 1))

x[slc].shape
# Out:
# (256, 1)

# %%
int(np.floor((62-256)/128 + 1) - 1)
# Out:
# -2
